# %% [markdown]
# ## Curso NumPy
#
# Intrutor: Rafael F.V.C. Santos
#
# Canal YouTube: https://bit.ly/CanalYouTube-Analistas-Quant
#
# Curso Python Fundamentos (Grátis): http://bit.ly/python-fundamentos

# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.21.6'

# %%
X = np.array([1,2,3],[4,5,6])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-97cc03005463> in <module>()
# ----> 1 X = np.array([1,2,3],[4,5,6])
#
# TypeError: Field elements must be 2- or 3-tuples, got '4'

# %%
X = np.array([[1,2,3],[4,5,6]], dtype=np.int32 )

# %%
X
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]], dtype=int32)

# %%
# Tipos e dimensões dos objetos arrays

# %%
type(X)
# Out:
# numpy.ndarray

# %%
X.shape
# Out:
# (2, 3)

# %%
# Não devemos utilizar () pois shape é um atributo do objeto
X.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-386b8665a4c0> in <module>()
# ----> 1 X.shape()
#
# TypeError: 'tuple' object is not callable

# %%
# Guardando dimensões do array

# %%
n, m = X.shape

# %%
n
# Out:
# 2

# %%
m
# Out:
# 3

# %%
type(X.shape)
# Out:
# tuple

# %%
n = X.shape[0]

# %%
m = X.shape[1]

# %%
X.shape(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-b07fb29b9fa4> in <module>()
# ----> 1 X.shape(0)
#
# TypeError: 'tuple' object is not callable

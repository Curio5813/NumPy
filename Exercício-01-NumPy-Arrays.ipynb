# %% [markdown]
# ## Curso NumPy  - Exercício 01
#
# Intrutor: Rafael F.V.C. Santos
#
# Canal YouTube: https://bit.ly/CanalYouTube-Analistas-Quant
#
# Curso Python Fundamentos (Grátis): http://bit.ly/python-fundamentos

# %% [markdown]
# # Exercício 01 - Avaliar igualdade de vetores e seus elementos
#
# - A partir de dois vetores: x e y;
#
# - Construir uma função/algoritmo para avaliar se dois vetores são iguais ou diferentes;
#
# - Apresentar os elementos iguais dos vetores;
#
# - Comparar elemento por elemento dos vetores apresentar índices onde os valores são iguais nos dois vetores.

# %%
import numpy as np

# %%
x = np.array([1.0, 3. , 2.6, 4.3, 7.7, 5.6])
y = np.array([1. , 2.6 , 3., 4. , 7. , 5.6])

# %%
x = np.array([1.0, 3. , 2.6, 4.3, 7.7, 5.6])
y = np.array([1.0, 3. , 2.6, 4.3, 7.7, 5.6])

# %%
x = np.array([1.5, 3. , 2.6, 43.3, 73.7, 5.36])
y = np.array([1.0, 3.3 , 2.36, 4.3, 7.73, 5.6])

# %%
cmp = x == y

# %%
# Dicas para resolver o exercício 01

# %%
cmp.all()
# Out:
# True

# %%
cmp.any()
# Out:
# False

# %%
np.where(x==y)
# Out:
# (array([0, 5]),)

# %% [markdown]
# ## Solução do Exercício 01

# %%
x = np.array([1.0, 3. , 2.6, 4.3, 7.7, 5.6])
y = np.array([1. , 2.6 , 3., 4. , 7. , 5.6])

# %%
cmp = x==y

# %%
cmp
# Out:
# array([ True, False, False, False, False,  True])

# %%
i = 0

if(cmp.all()):
  print('Todos os elementos são iguais!')
elif(cmp.any()):
  print('Alguns elementos são iguais, são eles:')
  for e in cmp:
    if(e):
      print('%.1f'% y[i])
    i += 1 # i = i + 1
  
  print('-------------')
  for e in x:
    j = np.where(e == y) # indexação de igual
    print(j)
    if(j[0].size != 0):
      print(y[j])
else:
  print('Todos os elementos são diferentes.')
# Out:
# Alguns elementos são iguais, são eles:
# 1.0
# 5.6
# -------------
# (array([0]),)
# [1.]
# (array([2]),)
# [3.]
# (array([1]),)
# [2.6]
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([5]),)
# [5.6]
